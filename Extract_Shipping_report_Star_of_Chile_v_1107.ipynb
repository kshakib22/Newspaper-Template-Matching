# %% [markdown]
# <a href="https://colab.research.google.com/github/kshakib22/Newspaper-Template-Matching/blob/main/Extract_Shipping_report_Star_of_Chile_v_1107.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing external libraries through `!pip`, connecting google drive storage, and importing modules.

# %%
# %%capture
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install pdf2image Pillow
# !apt-get install poppler-utils
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
import cv2
import os
import time
import tensorflow as tf
import sys
import numpy as np
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from pdf2image import convert_from_path

# %% [markdown]
# # Conversion of input files (.pdf) to .jpg format using 300dpi

# %%
"""
Convert PDF files in a given folder to individual images and save them in an output folder.

Parameters:
    pdf_folder (str): The path to the folder containing the PDF files.
    output_folder (str): The path to the folder where the converted images will be saved.

Returns:
    None

Dependencies:
    This function requires the 'os' module and the 'pdf2image' library to be installed.
    You can install 'pdf2image' using the following command: !pip install pdf2image

Description:
    This function takes the path to a folder containing PDF files (pdf_folder) and an output folder path (output_folder).
    It then converts each PDF file to images and saves them in the output folder as JPEG images.
    The function uses the 'pdf2image' library to perform the PDF to image conversion.
"""
def convert_pdf_to_images(pdf_folder, output_folder):
    # Get a list of PDF files in the input folder
    pdf_files = [filename for filename in os.listdir(pdf_folder) if filename.endswith('.pdf')]

    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    for filename in pdf_files:
        # Construct the full paths for input PDF and output images
        pdf_path = os.path.join(pdf_folder, filename)
        output_path = os.path.join(output_folder, os.path.splitext(filename)[0])

        # Convert PDF pages to images using pdf2image
        images = convert_from_path(pdf_path, dpi=300, grayscale=False)

        # Save each image as JPEG in the output folder
        for i, image in enumerate(images):
            image_path = f"{output_path}_{i}.jpg"
            image.save(image_path, "JPEG")

        print(f"PDF '{filename}' converted to images.")

    print("Conversion completed.")

# %%
pdf_path = "/content/drive/MyDrive/Summer 2023 project/complete_pdfs"
output= "/content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images"

convert_pdf_to_images(pdf_path, output)

# %% [markdown]
# # Template Matching

# %%
def perform_template_matching(image, template):
    """
    Perform template matching on the given image using the provided template.

    Parameters:
        image (numpy array): The input image on which template matching will be performed.
        template (numpy array): The template image used for matching.

    Returns:
        Tuple: A tuple containing the maximum correlation value and the location of the best match.
    """
    result = cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)
    _, max_val, _, max_loc = cv2.minMaxLoc(result)
    return max_val, max_loc

def crop_and_export(image, top_left, bottom_right, output_path):
    """
    Crop a specified region from the input image and export it as a new image.

    Parameters:
        image (numpy array): The input image from which the region will be cropped.
        top_left (tuple): The coordinates of the top-left corner of the region to be cropped.
        bottom_right (tuple): The coordinates of the bottom-right corner of the region to be cropped.
        output_path (str): The path to save the cropped image.

    Returns:
        None
    """
    cropped_image = image[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
    cv2.imwrite(output_path, cropped_image)
    print(f"Image saved: {output_path}")


def second_scenario(image, template_path, output_folder):
    """
    Perform the second scenario for template matching and crop the image if a match is found.
    Second scenario is considered when shipping report (template 1) is only a decent match but
    charters (template 2) is a pretty good match.

    Parameters:
        image (numpy array): The input image on which template matching will be performed.
        template_path (str): The path to the template image used for matching.
        output_folder (str): The path to the folder where the cropped image will be saved.

    Returns:
        None
    """
    # Load the template image
    template = cv2.imread(template_path)

    # Convert the template and image to grayscale
    template_gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Perform template matching
    result = cv2.matchTemplate(image_gray, template_gray, cv2.TM_CCOEFF_NORMED)
    _, max_val, _, max_loc = cv2.minMaxLoc(result)

    if max_val >= 0.4:
        height, width = image.shape[:2]
        line_length = int(width * 0.385)
        mid_point = (max_loc[0] + template_gray.shape[1] // 2, max_loc[1])
        top_left = (mid_point[0] - line_length // 2, 0)
        bottom_right = (mid_point[0] + line_length // 2, max_loc[1])

        if top_left[0] < 0:
            top_left = (0, top_left[1])

        try:
            crop_and_export(image, top_left, bottom_right, output_folder)
        except Exception as e:
            print("Error occurred for second scenario:", str(e))
    else:
        print("Template could not be used even in second scenario")

def third_scenario(image, template_path, output_folder):
    """
    Perform the third scenario for template matching and crop the image if a match is found.
    Third scenario is considered when shipping report (template 1) is a pretty good match but
    charters (template 2) is only a decent match.

    Parameters:
        image (numpy array): The input image on which template matching will be performed.
        template_path (str): The path to the template image used for matching.
        output_folder (str): The path to the folder where the cropped image will be saved.

    Returns:
        None
    """
    template = cv2.imread(template_path)
    template_gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Perform template matching
    result = cv2.matchTemplate(image_gray, template_gray, cv2.TM_CCOEFF_NORMED)
    _, max_val, _, max_loc = cv2.minMaxLoc(result)

    if max_val >= 0.34:
        x, y, w, h = max_loc[0], max_loc[1], template.shape[1], template.shape[0]
        bottom_x, bottom_y = x + w, image.shape[0]

        # Crop the portion within the green box
        cropped_image = image[y:bottom_y, x:bottom_x]

        # Save the cropped portion
        try:
          file_name = os.path.basename(image_path)
          output_path = os.path.join(output_folder, file_name)
          cv2.imwrite(output_path, cropped_image)
          print(f"Image saved: {output_path}")
        except Exception as e:
            print("Error occurred for third scenario:", str(e))
    else:
        print("Template match not found in third scenario")

def perform_image_processing(image_path, template1_path, template2_path, output_folder):
    """
    The main function to perform image processing and template matching on the input image
    using two template images.

    Parameters:
        image_path (str): The path to the input image for template matching.
        template1_path (str): The path to the first template image used for matching.
        template2_path (str): The path to the second template image used for matching.
        output_folder (str): The path to the folder where the cropped image will be saved.

    Returns:
        None
    """
    image = cv2.imread(image_path)
    template1 = cv2.imread(template1_path)
    template2 = cv2.imread(template2_path)

    # Convert images to grayscale for template matching
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    template1_gray = cv2.cvtColor(template1, cv2.COLOR_BGR2GRAY)
    template2_gray = cv2.cvtColor(template2, cv2.COLOR_BGR2GRAY)

    # Perform template matching
    similarity1, max_loc_1 = perform_template_matching(image_gray, template1_gray)
    similarity2, max_loc_2 = perform_template_matching(image_gray, template2_gray)

    print(f"Similarity1: {similarity1}")
    print(f"Similarity2: {similarity2}")

    # Ideal match conditions
    if similarity1 >= 0.78 and similarity2 >= 0.6:
        top = max_loc_1[1]
        bottom = max_loc_2[1]
        left = min(max_loc_1[0], max_loc_2[0])
        right = max(max_loc_1[0] + template1_gray.shape[1], max_loc_2[0] + template2_gray.shape[1])

        output_filename = os.path.splitext(os.path.basename(image_path))[0] + ".jpg"
        output_path = os.path.join(output_folder, output_filename)
        try:
            crop_and_export(image, (left, top), (right, bottom), output_path)
        except Exception as e:
            # This is when first condition fulfilled, but invalid dimensions.
            print("Error occurred in the first scenario: Invalid cropping dimensions")
            try:
                # Condition if shipping report is a decent match but charters is a good match
                if similarity1 >= 0.75 and similarity2 >= 0.62:
                    print("\nMoving to the second scenario...")
                    second_scenario(image, template2_path, output_path)

                # Condition if shipping report is a good match but charters is a decent match
                elif similarity1 >= 0.8 and similarity2 >= 0.58:
                    print("\nMoving to the third scenario...")
                    third_scenario(image, template1_path, output_folder)
                else:
                    print("Template matches not found or below similarity threshold.")
            except Exception as e:
                print("Error occurred:", str(e))

    # If first condition not satisfied, but no dimension error
    # Condition if shipping report is a decent match but charters is a good match
    elif similarity1 >= 0.75 and similarity2 >= 0.62:
        output_filename = os.path.splitext(os.path.basename(image_path))[0] + ".jpg"
        output_path = os.path.join(output_folder, output_filename)
        print("\nMoving to the second scenario...")
        second_scenario(image, template2_path, output_path)

    # Condition if shipping report is a good match but charters is a decent match
    elif similarity1 >= 0.8 and similarity2 >= 0.58:
        output_filename = os.path.splitext(os.path.basename(image_path))[0] + ".jpg"
        output_path = os.path.join(output_folder, output_filename)
        print("\nMoving to the third scenario...")
        third_scenario(image, template1_path, output_folder)
    else:
        print("Template matches not found or below similarity threshold.")

# %% [markdown]
# # Individual matching
# Perform template matching on a single image. This saves the cropped portion in the `output_path` if there is a valid match.

# %%
image_path = "/content/drive/MyDrive/Summer 2023 project/Images/17charter8.jpg"
template1_path = "/content/drive/MyDrive/Summer 2023 project/Images/17template_0.jpg"
template2_path = "/content/drive/MyDrive/Summer 2023 project/Images/17template.jpg"
output_path = "/content/drive/MyDrive/Summer 2023 project/Images/test/"
# Usage:
perform_image_processing(image_path, template1_path ,template2_path , output_path)
# Out:
# Similarity1: 0.9372795224189758
# Similarity2: 0.6756752729415894
# Image saved: /content/drive/MyDrive/Summer 2023 project/Images/test/17charter8.jpg

# %% [markdown]
# # Iterating through a folder containing images
#
# Perform template matching on a folder containing multiple images in a loop. All the matches are saved in the folder path given as `output_folder`

# %%
import os
import time
# Folder path containing images
input_folder = "/content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/"
output_folder = "/content/drive/MyDrive/Summer 2023 project/Images/all_shipping"
template1_path = "/content/drive/MyDrive/Summer 2023 project/Images/17template_0.jpg"
template2_path = "/content/drive/MyDrive/Summer 2023 project/Images/17template.jpg"

# Start the timer
start_time = time.time()

# Iterate through the image files in the input folder
for image_file in os.listdir(input_folder):
    # Get the full path of the image file
    image_path = os.path.join(input_folder, image_file)
    print(image_path)

    # Call the perform_image_processing function
    perform_image_processing(image_path, template1_path, template2_path, output_folder)

# Calculate the total time taken in hours
end_time = time.time()
time_taken = (end_time - start_time) / 3600

print(f"Total time taken: {time_taken} hours")
# Out:
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_9.jpg
# Similarity1: 0.5159093737602234
# Similarity2: 0.4501591920852661
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_5.jpg
# Similarity1: 0.40202441811561584
# Similarity2: 0.39501848816871643
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_8.jpg
# Similarity1: 0.34662091732025146
# Similarity2: 0.361337810754776
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_6.jpg
# Similarity1: 0.4691278338432312
# Similarity2: 0.3009428381919861
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_8.jpg
# Similarity1: 0.40762045979499817
# Similarity2: 0.39215826988220215
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_10.jpg
# Similarity1: 0.5635547637939453
# Similarity2: 0.39947086572647095
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_7.jpg
# Similarity1: 0.3855443000793457
# Similarity2: 0.3384053707122803
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_4.jpg
# Similarity1: 0.35812705755233765
# Similarity2: 0.28222712874412537
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_5.jpg
# Similarity1: 0.32419443130493164
# Similarity2: 0.3182346224784851
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_15.jpg
# Similarity1: 0.6218505501747131
# Similarity2: 0.42344722151756287
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_7.jpg
# Similarity1: 0.32557734847068787
# Similarity2: 0.31586840748786926
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_1.jpg
# Similarity1: 0.5631957054138184
# Similarity2: 0.40351781249046326
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_5.jpg
# Similarity1: 0.6472037434577942
# Similarity2: 0.3871428966522217
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_5.jpg
# Similarity1: 0.4234943091869354
# Similarity2: 0.31762591004371643
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_5.jpg
# Similarity1: 0.4715319573879242
# Similarity2: 0.3624827563762665
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_6.jpg
# Similarity1: 0.31825822591781616
# Similarity2: 0.31928902864456177
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_6.jpg
# Similarity1: 0.4024210274219513
# Similarity2: 0.3521396219730377
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_4.jpg
# Similarity1: 0.3705776035785675
# Similarity2: 0.4249827265739441
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_3.jpg
# Similarity1: 0.4394935965538025
# Similarity2: 0.4554295837879181
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_6.jpg
# Similarity1: 0.6221929788589478
# Similarity2: 0.3753594756126404
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_5.jpg
# Similarity1: 0.41184142231941223
# Similarity2: 0.3109728693962097
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_2.jpg
# Similarity1: 0.6809833645820618
# Similarity2: 0.4543387293815613
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_5.jpg
# Similarity1: 0.3588583469390869
# Similarity2: 0.3423447608947754
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_10.jpg
# Similarity1: 0.5522390007972717
# Similarity2: 0.39468109607696533
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_9.jpg
# Similarity1: 0.34078630805015564
# Similarity2: 0.3009192645549774
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_2.jpg
# Similarity1: 0.5828783512115479
# Similarity2: 0.44835129380226135
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_0.jpg
# Similarity1: 0.6353003978729248
# Similarity2: 0.43473607301712036
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_8.jpg
# Similarity1: 0.38327983021736145
# Similarity2: 0.30358031392097473
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_10.jpg
# Similarity1: 0.4639139175415039
# Similarity2: 0.3819654583930969
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_11.jpg
# Similarity1: 0.3765677511692047
# Similarity2: 0.285859078168869
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_2.jpg
# Similarity1: 0.27922987937927246
# Similarity2: 0.34315526485443115
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_0.jpg
# Similarity1: 0.6718196272850037
# Similarity2: 0.4501364827156067
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_0.jpg
# Similarity1: 0.6603313684463501
# Similarity2: 0.4339603781700134
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_3.jpg
# Similarity1: 0.37671422958374023
# Similarity2: 0.3861878216266632
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_6.jpg
# Similarity1: 0.4945007264614105
# Similarity2: 0.39120516180992126
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_0.jpg
# Similarity1: 0.5015503764152527
# Similarity2: 0.4543781280517578
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_11.jpg
# Similarity1: 0.586247980594635
# Similarity2: 0.46784132719039917
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_0.jpg
# Similarity1: 0.5017727017402649
# Similarity2: 0.4581911563873291
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_10.jpg
# Similarity1: 0.5089007616043091
# Similarity2: 0.38108018040657043
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_11.jpg
# Similarity1: 0.6142804026603699
# Similarity2: 0.42471691966056824
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_7.jpg
# Similarity1: 0.35321128368377686
# Similarity2: 0.26428258419036865
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_9.jpg
# Similarity1: 0.5123997330665588
# Similarity2: 0.38319411873817444
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_12.jpg
# Similarity1: 0.3809122145175934
# Similarity2: 0.3868696391582489
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_2.jpg
# Similarity1: 0.5715736150741577
# Similarity2: 0.45856624841690063
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_2.jpg
# Similarity1: 0.5823493599891663
# Similarity2: 0.44637325406074524
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_1.jpg
# Similarity1: 0.5762425065040588
# Similarity2: 0.41906121373176575
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_2.jpg
# Similarity1: 0.5480494499206543
# Similarity2: 0.38384729623794556
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_0.jpg
# Similarity1: 0.5929877161979675
# Similarity2: 0.4310770332813263
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_5.jpg
# Similarity1: 0.41320621967315674
# Similarity2: 0.41051942110061646
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_10.jpg
# Similarity1: 0.5495406985282898
# Similarity2: 0.399752676486969
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_8.jpg
# Similarity1: 0.44430842995643616
# Similarity2: 0.4309841990470886
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_3.jpg
# Similarity1: 0.17263749241828918
# Similarity2: 0.191648930311203
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_9.jpg
# Similarity1: 0.4608795642852783
# Similarity2: 0.3497244715690613
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_0.jpg
# Similarity1: 0.5872140526771545
# Similarity2: 0.3981495201587677
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_14.jpg
# Similarity1: 0.5738123059272766
# Similarity2: 0.3937895894050598
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_5.jpg
# Similarity1: 0.4067555367946625
# Similarity2: 0.3910331130027771
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_0.jpg
# Similarity1: 0.523497998714447
# Similarity2: 0.41715696454048157
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_11.jpg
# Similarity1: 0.5877916812896729
# Similarity2: 0.45001351833343506
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_9.jpg
# Similarity1: 0.5355467796325684
# Similarity2: 0.3140432834625244
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_1.jpg
# Similarity1: 0.6525796055793762
# Similarity2: 0.3714976906776428
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_1.jpg
# Similarity1: 0.6069809198379517
# Similarity2: 0.40646371245384216
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_5.jpg
# Similarity1: 0.39552563428878784
# Similarity2: 0.33007052540779114
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_9.jpg
# Similarity1: 0.47426727414131165
# Similarity2: 0.346770703792572
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_8.jpg
# Similarity1: 0.42855483293533325
# Similarity2: 0.39495667815208435
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_8.jpg
# Similarity1: 0.3563028573989868
# Similarity2: 0.31429341435432434
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_8.jpg
# Similarity1: 0.5400893688201904
# Similarity2: 0.3184136748313904
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_2.jpg
# Similarity1: 0.5609389543533325
# Similarity2: 0.4395955801010132
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_1.jpg
# Similarity1: 0.6411049962043762
# Similarity2: 0.3669479191303253
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_0.jpg
# Similarity1: 0.5504220128059387
# Similarity2: 0.46439194679260254
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_10.jpg
# Similarity1: 0.4790330231189728
# Similarity2: 0.4531131088733673
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_9.jpg
# Similarity1: 0.5224818587303162
# Similarity2: 0.31070736050605774
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_8.jpg
# Similarity1: 0.40522271394729614
# Similarity2: 0.400762140750885
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_6.jpg
# Similarity1: 0.4428914487361908
# Similarity2: 0.43627727031707764
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_1.jpg
# Similarity1: 0.6582663059234619
# Similarity2: 0.3925957977771759
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_0.jpg
# Similarity1: 0.24949754774570465
# Similarity2: 0.2630522549152374
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_11.jpg
# Similarity1: 0.6335717439651489
# Similarity2: 0.4716068506240845
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_9.jpg
# Similarity1: 0.3642105758190155
# Similarity2: 0.30876263976097107
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_7.jpg
# Similarity1: 0.34132120013237
# Similarity2: 0.2984125316143036
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_13.jpg
# Similarity1: 0.4623531401157379
# Similarity2: 0.37994593381881714
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_0.jpg
# Similarity1: 0.7169319987297058
# Similarity2: 0.4496966302394867
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_7.jpg
# Similarity1: 0.37515372037887573
# Similarity2: 0.3182280957698822
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_6.jpg
# Similarity1: 0.5993192791938782
# Similarity2: 0.3721559941768646
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_4.jpg
# Similarity1: 0.3492751121520996
# Similarity2: 0.29584306478500366
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_6.jpg
# Similarity1: 0.4969930648803711
# Similarity2: 0.3866675794124603
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_3.jpg
# Similarity1: 0.3412473499774933
# Similarity2: 0.3770357668399811
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_3.jpg
# Similarity1: 0.3833131790161133
# Similarity2: 0.3922422528266907
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_3.jpg
# Similarity1: 0.3416634798049927
# Similarity2: 0.399245023727417
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_6.jpg
# Similarity1: 0.5949803590774536
# Similarity2: 0.3911227881908417
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_8.jpg
# Similarity1: 0.3877776563167572
# Similarity2: 0.35651886463165283
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_2.jpg
# Similarity1: 0.6634820699691772
# Similarity2: 0.44382476806640625
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_7.jpg
# Similarity1: 0.35525283217430115
# Similarity2: 0.2643970549106598
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_7.jpg
# Similarity1: 0.3742751181125641
# Similarity2: 0.2940934896469116
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_2.jpg
# Similarity1: 0.5593491196632385
# Similarity2: 0.43920978903770447
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_0.jpg
# Similarity1: 0.5291581749916077
# Similarity2: 0.46242237091064453
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_1.jpg
# Similarity1: 0.6275047659873962
# Similarity2: 0.3712397813796997
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_1.jpg
# Similarity1: 0.6975530385971069
# Similarity2: 0.38513806462287903
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_10.jpg
# Similarity1: 0.44756391644477844
# Similarity2: 0.39044269919395447
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_2.jpg
# Similarity1: 0.6829202175140381
# Similarity2: 0.4679989814758301
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_11.jpg
# Similarity1: 0.6377477645874023
# Similarity2: 0.4504983723163605
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_11.jpg
# Similarity1: 0.553257167339325
# Similarity2: 0.4388883113861084
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_4.jpg
# Similarity1: 0.4431699216365814
# Similarity2: 0.33671891689300537
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_4.jpg
# Similarity1: 0.46813154220581055
# Similarity2: 0.4347262680530548
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_11.jpg
# Similarity1: 0.6041556596755981
# Similarity2: 0.4221523404121399
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_0.jpg
# Similarity1: 0.5046070218086243
# Similarity2: 0.46218717098236084
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_11.jpg
# Similarity1: 0.6319224238395691
# Similarity2: 0.4673806428909302
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_10.jpg
# Similarity1: 0.41953080892562866
# Similarity2: 0.3829239010810852
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_4.jpg
# Similarity1: 0.36130180954933167
# Similarity2: 0.26782602071762085
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_10.jpg
# Similarity1: 0.4735638499259949
# Similarity2: 0.39197003841400146
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_3.jpg
# Similarity1: 0.49687328934669495
# Similarity2: 0.39941906929016113
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_7.jpg
# Similarity1: 0.3418462574481964
# Similarity2: 0.29656821489334106
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_10.jpg
# Similarity1: 0.6212072372436523
# Similarity2: 0.3913659155368805
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_3.jpg
# Similarity1: 0.38091903924942017
# Similarity2: 0.4293869137763977
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_7.jpg
# Similarity1: 0.3815156817436218
# Similarity2: 0.33962443470954895
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_1.jpg
# Similarity1: 0.5950623750686646
# Similarity2: 0.3885093033313751
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_11.jpg
# Similarity1: 0.6049350500106812
# Similarity2: 0.45499905943870544
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_11.jpg
# Similarity1: 0.5966097116470337
# Similarity2: 0.4534951448440552
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_3.jpg
# Similarity1: 0.3834647238254547
# Similarity2: 0.40014147758483887
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_7.jpg
# Similarity1: 0.3300797939300537
# Similarity2: 0.3403746485710144
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_1.jpg
# Similarity1: 0.22677168250083923
# Similarity2: 0.3126267194747925
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_2.jpg
# Similarity1: 0.6536167860031128
# Similarity2: 0.4584479331970215
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_9.jpg
# Similarity1: 0.5166559815406799
# Similarity2: 0.3415345847606659
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_1.jpg
# Similarity1: 0.6945291757583618
# Similarity2: 0.38375747203826904
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_8.jpg
# Similarity1: 0.5212350487709045
# Similarity2: 0.3839043974876404
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_9.jpg
# Similarity1: 0.5128535628318787
# Similarity2: 0.3982154428958893
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_4.jpg
# Similarity1: 0.4319947063922882
# Similarity2: 0.33210259675979614
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_9.jpg
# Similarity1: 0.49945834279060364
# Similarity2: 0.32404276728630066
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_11.jpg
# Similarity1: 0.5849904417991638
# Similarity2: 0.4500865638256073
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_10.jpg
# Similarity1: 0.4901847243309021
# Similarity2: 0.3904189169406891
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_6.jpg
# Similarity1: 0.6160458922386169
# Similarity2: 0.449825257062912
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_11.jpg
# Similarity1: 0.62305748462677
# Similarity2: 0.48665857315063477
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_8.jpg
# Similarity1: 0.5292983651161194
# Similarity2: 0.37358394265174866
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_5.jpg
# Similarity1: 0.3938688039779663
# Similarity2: 0.3281170725822449
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_0.jpg
# Similarity1: 0.7120895385742188
# Similarity2: 0.40545210242271423
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_3.jpg
# Similarity1: 0.38015076518058777
# Similarity2: 0.37833455204963684
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_4.jpg
# Similarity1: 0.45531174540519714
# Similarity2: 0.41879135370254517
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_9.jpg
# Similarity1: 0.580665111541748
# Similarity2: 0.46369466185569763
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_6.jpg
# Similarity1: 0.4408409297466278
# Similarity2: 0.3977454602718353
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_5.jpg
# Similarity1: 0.31106096506118774
# Similarity2: 0.37137770652770996
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_7.jpg
# Similarity1: 0.32110723853111267
# Similarity2: 0.26076382398605347
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_1.jpg
# Similarity1: 0.670451819896698
# Similarity2: 0.36958253383636475
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_2.jpg
# Similarity1: 0.551788866519928
# Similarity2: 0.43126538395881653
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0007_9.jpg
# Similarity1: 0.5436632037162781
# Similarity2: 0.2982264757156372
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_4.jpg
# Similarity1: 0.49362027645111084
# Similarity2: 0.4165699779987335
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_6.jpg
# Similarity1: 0.34108883142471313
# Similarity2: 0.3455231189727783
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_9.jpg
# Similarity1: 0.5669669508934021
# Similarity2: 0.3559102416038513
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0003_3.jpg
# Similarity1: 0.4327511489391327
# Similarity2: 0.35072585940361023
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_2.jpg
# Similarity1: 0.5341786742210388
# Similarity2: 0.4063290059566498
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_10.jpg
# Similarity1: 0.5456441044807434
# Similarity2: 0.3846992552280426
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_8.jpg
# Similarity1: 0.41718852519989014
# Similarity2: 0.3840878903865814
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_3.jpg
# Similarity1: 0.4153786897659302
# Similarity2: 0.4080449938774109
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_4.jpg
# Similarity1: 0.3750521242618561
# Similarity2: 0.3442784249782562
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_6.jpg
# Similarity1: 0.562627911567688
# Similarity2: 0.4742474853992462
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_2.jpg
# Similarity1: 0.6402052640914917
# Similarity2: 0.4238104224205017
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_7.jpg
# Similarity1: 0.3978152275085449
# Similarity2: 0.2843136787414551
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0005_5.jpg
# Similarity1: 0.43477144837379456
# Similarity2: 0.3437979221343994
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_7.jpg
# Similarity1: 0.34394872188568115
# Similarity2: 0.31121015548706055
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0001_6.jpg
# Similarity1: 0.537358820438385
# Similarity2: 0.43599584698677063
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0008_11.jpg
# Similarity1: 0.6014343500137329
# Similarity2: 0.4595564007759094
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_5.jpg
# Similarity1: 0.47397661209106445
# Similarity2: 0.3412214517593384
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0011_4.jpg
# Similarity1: 0.3667391240596771
# Similarity2: 0.29429471492767334
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_1.jpg
# Similarity1: 0.6674098372459412
# Similarity2: 0.4102972745895386
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_8.jpg
# Similarity1: 0.4342072010040283
# Similarity2: 0.3525916337966919
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_4.jpg
# Similarity1: 0.398064523935318
# Similarity2: 0.343938946723938
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0012_3.jpg
# Similarity1: 0.3714159429073334
# Similarity2: 0.3787650465965271
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0004_8.jpg
# Similarity1: 0.4387204647064209
# Similarity2: 0.30504000186920166
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_10.jpg
# Similarity1: 0.5706982612609863
# Similarity2: 0.39718884229660034
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0013_10.jpg
# Similarity1: 0.5492944121360779
# Similarity2: 0.3889196217060089
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0009_7.jpg
# Similarity1: 0.3470041751861572
# Similarity2: 0.31452476978302
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0006_3.jpg
# Similarity1: 0.35414475202560425
# Similarity2: 0.32999953627586365
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0014_4.jpg
# Similarity1: 0.4236052930355072
# Similarity2: 0.3431461751461029
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0010_4.jpg
# Similarity1: 0.3902774751186371
# Similarity2: 0.4406120181083679
# Template matches not found or below similarity threshold.
# /content/drive/MyDrive/Summer 2023 project/Images/converted_pdf_images/PE0001108/PE0001108_0002_1.jpg
# Similarity1: 0.674586832523346
# Similarity2: 0.3864949941635132
# Template matches not found or below similarity threshold.
# Total time taken: 0.15586365699768068 hours
